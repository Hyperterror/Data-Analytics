# %% [markdown]
# # DA-AG-009 EDA
#
# Answers prepared in notebook format.

# %% [markdown]
# ## Q1. Read the Bike Details dataset into a Pandas DataFrame and display its first 10 rows. Show the shape and column names.
#
# Use pandas read_csv to load the dataset, then use head(10), shape, and columns to inspect the data.

# %% [markdown]
# ## Q2. Check for missing values in all columns and describe your approach for handling them.
#
# Use isna().sum() to identify missing values. Handle them by dropping columns or rows with too many missing values and imputing the rest based on column type.

# %% [markdown]
# ## Q3. Plot the distribution of selling prices using a histogram and describe the overall trend.
#
# A histogram will likely show whether selling prices are skewed, centered around a range, or contain outliers.

# %% [markdown]
# ## Q4. Create a bar plot to visualize the average selling price for each seller type and write one observation.
#
# Group by seller type, calculate mean selling price, and plot the result. The observation should mention which seller type generally has higher average prices.

# %% [markdown]
# ## Q5. Compute the average km driven for each ownership type and present the result as a bar plot.
#
# Group by ownership type, compute average km driven, and visualize with a bar chart.

# %% [markdown]
# ## Q6. Use the IQR method to detect and remove outliers from the km driven column. Show before-and-after summary statistics.
#
# Compute Q1, Q3, and IQR, filter values outside the whisker bounds, and compare descriptive statistics before and after removal.

# %% [markdown]
# ## Q7. Create a scatter plot of year vs. selling price to explore the relationship between bike age and price.
#
# Plot year on the x-axis and selling price on the y-axis. Typically, newer bikes tend to have higher prices.

# %% [markdown]
# ## Q8. Convert the seller type column into numeric format using one-hot encoding. Display the first 5 rows.
#
# Use pandas get_dummies to encode the seller type column and show the first five rows of the transformed DataFrame.

# %% [markdown]
# ## Q9. Generate a heatmap of the correlation matrix for all numeric columns. What correlations stand out the most?
#
# Use a correlation matrix and heatmap to identify the strongest positive and negative relationships among numeric variables.

# %% [markdown]
# ## Q10. Summarize your findings in a brief report.
#
# Summarize key price drivers such as year, km driven, ownership, and seller type, and mention the cleaning or encoding steps used.
