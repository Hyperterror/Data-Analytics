# %% [markdown]
# # Data Toolkit Assignment
#
# Updated with practical answers and code snippets.

# %% [markdown]
# ## Theory Answers
#
# **1. What is NumPy, and why is it widely used in Python?**
# NumPy (Numerical Python) is a foundational library for scientific computing. It provides the `ndarray` object — a fast, memory-efficient N-dimensional array — along with a comprehensive set of mathematical functions. It is widely used because array operations are vectorized (no Python loops needed), making computations orders of magnitude faster than plain Python lists.
#
# **2. How does broadcasting work in NumPy?**
# Broadcasting allows NumPy to perform arithmetic operations on arrays of different shapes by automatically expanding the smaller array to match the larger one during the operation, without copying data. Rules: dimensions are compared from the right; each dimension must either be equal or one of them must be 1.
# Example: adding a (3,) array to a (4,3) array broadcasts the (3,) array across all 4 rows.
#
# **3. What is a Pandas DataFrame?**
# A DataFrame is a two-dimensional, size-mutable, labeled data structure with columns of potentially different data types, similar to a spreadsheet or SQL table. It is the primary Pandas data structure. Each column is a Series, and rows are accessed by an index.
#
# **4. Explain the use of the `groupby()` method in Pandas.**
# `groupby()` splits a DataFrame into groups based on one or more columns, applies an aggregation or transformation function to each group, and combines the results. It follows the Split-Apply-Combine pattern. Example: `df.groupby('Category')['Sales'].sum()` sums Sales for each unique Category.
#
# **5. Why is Seaborn preferred for statistical visualizations?**
# Seaborn is built on top of Matplotlib and provides a high-level interface for drawing attractive statistical graphics. It has built-in themes, automatic handling of Pandas DataFrames, and specialized plot types like violin plots, pair plots, heatmaps, and distribution plots that would require many lines of Matplotlib code.
#
# **6. What are the differences between NumPy arrays and Python lists?**
# | Feature | NumPy Array | Python List |
# |---|---|---|
# | Data type | Homogeneous (all same type) | Heterogeneous |
# | Speed | Much faster (vectorized C operations) | Slower (interpreted Python) |
# | Memory | Contiguous memory block (efficient) | Scattered pointers (less efficient) |
# | Operations | Supports element-wise math directly | Requires explicit loops |
# | Dimensions | N-dimensional (tensors) | Only 1D natively |
#
# **7. What is a heatmap, and when should it be used?**
# A heatmap is a 2D visualization that uses color intensity to represent the magnitude of values in a matrix. It should be used when comparing relationships across multiple variables simultaneously, such as a correlation matrix, confusion matrix, or frequency table.
#
# **8. What does the term 'vectorized operation' mean in NumPy?**
# A vectorized operation applies a function or arithmetic operator element-wise across an entire array without writing explicit Python loops. NumPy delegates these operations to pre-compiled C routines, making them dramatically faster. Example: `arr * 2` doubles every element in one call instead of looping.
#
# **9. How does Matplotlib differ from Plotly?**
# - *Matplotlib* produces static, publication-quality plots. Highly customizable but requires more code. Best for scripts, reports, and academic papers.
# - *Plotly* produces interactive, web-based charts (zoom, pan, hover tooltips). Best for dashboards and web applications. Works well with Jupyter notebooks.
#
# **10. What is the significance of hierarchical indexing in Pandas?**
# Hierarchical (or multi-level) indexing allows a DataFrame to have multiple index levels, enabling representation of higher-dimensional data in a 2D structure. It is useful for groupby results, time-series data with multiple identifiers, and cross-sectional data. Accessed using `.loc[]` with tuples or `.xs()` for cross-sections.
#
# **11. What is the role of Seaborn's `pairplot()` function?**
# `pairplot()` creates a grid of scatter plots for every pair of numerical features in a dataset, with histograms or KDE plots along the diagonal. It provides a quick overview of pairwise relationships and distributions, and can be colored by a categorical variable to reveal class separability.
#
# **12. What is the purpose of the `describe()` function in Pandas?**
# `describe()` generates descriptive statistics for each numerical column: count, mean, standard deviation, minimum, 25th percentile (Q1), median (Q2), 75th percentile (Q3), and maximum. It gives a quick statistical summary of the data distribution.
#
# **13. Why is handling missing data important in Pandas?**
# Missing values (NaN) can cause incorrect calculations, model failures, and biased results. Proper handling — through deletion, imputation, or flagging — ensures data quality and analytical accuracy. Pandas provides `isnull()`, `dropna()`, and `fillna()` for this purpose.
#
# **14. What are the benefits of using Plotly for data visualization?**
# - Interactive charts: zoom, pan, hover, select.
# - Supports 3D plots, animated charts, maps, and dashboards.
# - Integrates easily with Jupyter, Dash, and web frameworks.
# - Produces web-ready HTML exports.
# - Works with Pandas DataFrames natively via Plotly Express.
#
# **15. How does NumPy handle multidimensional arrays?**
# NumPy uses the `ndarray` object which stores data in a contiguous memory block with shape (dimensions), dtype (data type), and strides (bytes between elements). Arrays can be reshaped with `.reshape()`, stacked with `np.stack()`/`np.concatenate()`, and sliced using multi-dimensional indexing. Operations broadcast across axes using `axis` parameters.
#
# **16. What is the role of Bokeh?**
# Bokeh is a Python library for creating interactive visualizations for web browsers. It renders output as JavaScript-powered HTML, supports streaming and real-time data, and is particularly suited for building interactive dashboards and data applications. Like Plotly, it supports hover tools, sliders, and widgets, but has a lower-level API that gives more control over rendering.

# %% [markdown]
# ## Practical 1. 2D NumPy array and row sums
#
# ```python
# import numpy as np
# a = np.array([[1,2,3],[4,5,6]])
# print(a.sum(axis=1))
# ```

# %% [markdown]
# ## Practical 2. Mean of a specific DataFrame column
#
# ```python
# import pandas as pd
# df = pd.DataFrame({"A":[10,20,30],"B":[1,2,3]})
# print(df["A"].mean())
# ```

# %% [markdown]
# ## Practical 3. Scatter plot using Matplotlib
#
# ```python
# import matplotlib.pyplot as plt
# x = [1,2,3,4]
# y = [2,4,6,8]
# plt.scatter(x,y)
# plt.show()
# ```

# %% [markdown]
# ## Practical 4. Correlation matrix with heatmap
#
# ```python
# import pandas as pd, seaborn as sns, matplotlib.pyplot as plt
# df = pd.DataFrame({"A":[1,2,3],"B":[2,4,6],"C":[5,6,7]})
# sns.heatmap(df.corr(), annot=True)
# plt.show()
# ```

# %% [markdown]
# ## Practical 5. Bar plot using Plotly
#
# ```python
# import plotly.express as px
# df = px.data.tips()
# fig = px.bar(df, x="day", y="total_bill")
# fig.show()
# ```

# %% [markdown]
# ## Practical 6. Add a new DataFrame column
#
# ```python
# import pandas as pd
# df = pd.DataFrame({"marks":[50,60,70]})
# df["double_marks"] = df["marks"] * 2
# print(df)
# ```

# %% [markdown]
# ## Practical 7. Element-wise multiplication of arrays
#
# ```python
# import numpy as np
# a = np.array([1,2,3])
# b = np.array([4,5,6])
# print(a * b)
# ```

# %% [markdown]
# ## Practical 8. Multiple line plot
#
# ```python
# import matplotlib.pyplot as plt
# x = [1,2,3]
# y1 = [1,4,9]
# y2 = [1,2,3]
# plt.plot(x,y1,label="square")
# plt.plot(x,y2,label="linear")
# plt.legend()
# plt.show()
# ```

# %% [markdown]
# ## Practical 9. Filter rows in DataFrame
#
# ```python
# import pandas as pd
# df = pd.DataFrame({"A":[10,25,30]})
# print(df[df["A"] > 20])
# ```

# %% [markdown]
# ## Practical 10. Histogram using Seaborn
#
# ```python
# import seaborn as sns, matplotlib.pyplot as plt
# sns.histplot([1,2,2,3,3,3,4])
# plt.show()
# ```

# %% [markdown]
# ## Practical 11. Matrix multiplication
#
# ```python
# import numpy as np
# a = np.array([[1,2],[3,4]])
# b = np.array([[5,6],[7,8]])
# print(np.matmul(a,b))
# ```

# %% [markdown]
# ## Practical 12. Load CSV and display first 5 rows
#
# ```python
# import pandas as pd
# df = pd.read_csv("sample.csv")
# print(df.head())
# ```

# %% [markdown]
# ## Practical 13. 3D scatter plot using Plotly
#
# ```python
# import plotly.express as px
# df = px.data.iris()
# fig = px.scatter_3d(df, x="sepal_length", y="sepal_width", z="petal_length", color="species")
# fig.show()
# ```
